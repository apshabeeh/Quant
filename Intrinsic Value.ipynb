# %% [markdown]
# ##Intrinsic Value Calculation
#
# -Gross Profit Margin > 20
# -Return on Equity > 25

# %%
import yfinance as yf
import pandas as pd
import yfinance as yf

msft = yf.Ticker("SBIN.NS")

# get stock info
msft.info
# Out:
# {'zip': '400021',
#  'sector': 'Financial Services',
#  'fullTimeEmployees': 245652,
#  'longBusinessSummary': "State Bank of India provides various banking products and services to individuals, commercial enterprises, corporates, public bodies, and institutional customers in India and internationally. The company operates through Treasury, Corporate/Wholesale Banking, Retail Banking, Insurance Business, and Other Banking Business segments. It offers personal banking products and services, including current accounts, savings accounts, term deposits, and recurring deposits; home, auto, education, gold, and personal loans, as well as loans against property and securities; and wealth management, mobile and internet banking, demat, foreign inward remittance, safe deposit locker, public provident fund, money transfer, pension policy, and mobile wallet services, as well as cards and inflation indexed national savings securities cumulative bonds. The company also provides corporate banking products and services comprising corporate accounts, working capital and project finance, term loans, deferred payment guarantees, corporate loans, structured finance, dealer and channel financing, equipment leasing, loan syndication, construction equipment loans, financing Indian firms' overseas subsidiaries or JVs, and cash management, as well as export and cash, and letters of credit products. In addition, it offers NRI services, including accounts and deposits, remittances, investments, and loans; agricultural banking and micro credit to agriculturists and farmers; supply chain finance, and deposits and transaction banking services for SME customers; and international banking services. Further, the company provides treasury, broking, bill payment, and MICR services; and credit cards, life and non-life insurance, mutual funds, merchant banking, trustee business, factoring, security trading, pension fund management, and custody services. As of March 31, 2021, it operated 22,219 branches and 62,617 ATMs. The company was founded in 1806 and is headquartered in Mumbai, India.",
#  'city': 'Mumbai',
#  'phone': '91 22 2274 0841',
#  'country': 'India',
#  'companyOfficers': [],
#  'website': 'http://www.sbi.co.in',
#  'maxAge': 1,
#  'address1': 'State Bank Bhavan',
#  'fax': '91 22 2285 5348',
#  'industry': 'Banks—Regional',
#  'address2': '14th Floor Corporate Centre Madame Cama Road, Nariman Point',
#  'previousClose': 420.25,
#  'regularMarketOpen': 423.9,
#  'twoHundredDayAverage': 349.18228,
#  'trailingAnnualDividendYield': 0.009518144,
#  'payoutRatio': 0,
#  'volume24Hr': None,
#  'regularMarketDayHigh': 423.9,
#  'navPrice': None,
#  'averageDailyVolume10Day': 27129047,
#  'totalAssets': None,
#  'regularMarketPreviousClose': 420.25,
#  'fiftyDayAverage': 399.9111,
#  'trailingAnnualDividendRate': 4,
#  'open': 423.9,
#  'toCurrency': None,
#  'averageVolume10days': 27129047,
#  'expireDate': None,
#  'yield': None,
#  'algorithm': None,
#  'dividendRate': 4,
#  'exDividendDate': 1622678400,
#  'beta': 1.072322,
#  'circulatingSupply': None,
#  'startDate': None,
#  'regularMarketDayLow': 402.65,
#  'priceHint': 2,
#  'currency': 'INR',
#  'trailingPE': 16.446922,
#  'regularMarketVolume': 45686692,
#  'lastMarket': None,
#  'maxSupply': None,
#  'openInterest': None,
#  'marketCap': 3684971315200,
#  'volumeAllCurrencies': None,
#  'strikePrice': None,
#  'averageVolume': 49424467,
#  'priceToSalesTrailing12Months': 2.1258383,
#  'dayLow': 402.65,
#  'ask': 0,
#  'ytdReturn': None,
#  'askSize': 0,
#  'volume': 45686692,
#  'fiftyTwoWeekHigh': 441.95,
#  'forwardPE': 14.213426,
#  'fromCurrency': None,
#  'fiveYearAvgDividendYield': None,
#  'fiftyTwoWeekLow': 175.5,
#  'bid': 0,
#  'tradeable': False,
#  'dividendYield': 0.0097,
#  'bidSize': 0,
#  'dayHigh': 423.9,
#  'exchange': 'NSI',
#  'shortName': 'STATE BK OF INDIA',
#  'longName': 'State Bank of India',
#  'exchangeTimezoneName': 'Asia/Kolkata',
#  'exchangeTimezoneShortName': 'IST',
#  'isEsgPopulated': False,
#  'gmtOffSetMilliseconds': '19800000',
#  'quoteType': 'EQUITY',
#  'symbol': 'SBIN.NS',
#  'messageBoardId': 'finmb_874487',
#  'market': 'in_market',
#  'annualHoldingsTurnover': None,
#  'enterpriseToRevenue': 3.774,
#  'beta3Year': None,
#  'profitMargins': 0.12925,
#  'enterpriseToEbitda': None,
#  '52WeekChange': 1.1997869,
#  'morningStarRiskRating': None,
#  'forwardEps': 29.05,
#  'revenueQuarterlyGrowth': None,
#  'sharesOutstanding': 8924609536,
#  'fundInceptionDate': None,
#  'annualReportExpenseRatio': None,
#  'bookValue': 308.766,
#  'sharesShort': None,
#  'sharesPercentSharesOut': None,
#  'fundFamily': None,
#  'lastFiscalYearEnd': 1617148800,
#  'heldPercentInstitutions': 0.26512,
#  'netIncomeToCommon': 224054575104,
#  'trailingEps': 25.105,
#  'lastDividendValue': 4,
#  'SandP52WeekChange': 0.35408902,
#  'priceToBook': 1.3372587,
#  'heldPercentInsiders': 0.56918997,
#  'nextFiscalYearEnd': 1680220800,
#  'mostRecentQuarter': 1617148800,
#  'shortRatio': None,
#  'sharesShortPreviousMonthDate': None,
#  'floatShares': 3827319656,
#  'enterpriseValue': 6541718585344,
#  'threeYearAverageReturn': None,
#  'lastSplitDate': 1416441600,
#  'lastSplitFactor': '10:1',
#  'legalType': None,
#  'lastDividendDate': 1622678400,
#  'morningStarOverallRating': None,
#  'earningsQuarterlyGrowth': -0.114,
#  'dateShortInterest': None,
#  'pegRatio': None,
#  'lastCapGain': None,
#  'shortPercentOfFloat': None,
#  'sharesShortPriorMonth': None,
#  'impliedSharesOutstanding': None,
#  'category': None,
#  'fiveYearAverageReturn': None,
#  'regularMarketPrice': 412.9,
#  'logo_url': 'https://logo.clearbit.com/sbi.co.in'}
